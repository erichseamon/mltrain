# %%
# %pylab inline
import pandas as pd
LoanData = pd.read_csv("/Users/erichs/Desktop/MLCONF/loanf.csv")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pd
from sklearn import tree

# %%
d = LoanData['TF']=LoanData['Interest.Rate']<=12
d.head()
# Out:
# 6     False
# 11    False
# 12    False
# 13    False
# 21    False
# Name: Interest.Rate, dtype: bool

# %%
d = LoanData['TF']=LoanData['Interest.Rate']<=10
d.head()
# Out:
# 6     False
# 11    False
# 12    False
# 13    False
# 21    False
# Name: Interest.Rate, dtype: bool

# %%
import statsmodels.api as sm

LoanData['intercept']=1.0
ind_cols=['FICO.Score', 'Loan.Amount','intercept']
logit = sm.Logit(LoanData['TF'], LoanData[ind_cols])
result=logit.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.279453
#          Iterations 8

# %%
coeff = result.params
print coeff
# Out:
# FICO.Score      0.072246
# Loan.Amount    -0.000152
# intercept     -51.157435
# dtype: float64

# %%
def pz(fico,amt,coeff):
    z = coeff[0]*fico + coeff[1]*amt + coeff[2]
    return 1/1+exp(-1*z))
# Out:
#   File "<ipython-input-32-7c605d677642>", line 3
#     return 1/1+exp(-1*z))
#                         ^
# SyntaxError: invalid syntax

# %%
pz(500,10000,coeff)
# Out:
# 15412369.621219413

# %%
from numpy import random, array
Social_Data = array(Social_Data)
Social_Data
# Out:
# array([[  1.83000000e+01,   2.00001200e+04],
#        [  7.25000000e+01,   1.99000340e+05],
#        [  2.25000000e+01,   3.45005600e+04],
#        [  3.56000000e+01,   7.50007800e+04],
#        [  3.59000000e+01,   1.10000890e+05],
#        [  6.51000000e+01,   2.20000120e+05],
#        [  6.53000000e+01,   2.10000120e+05],
#        [  6.61000000e+01,   2.20000120e+05],
#        [  6.71000000e+01,   2.40000120e+05],
#        [  6.91000000e+01,   2.20000120e+05],
#        [  1.93000000e+01,   2.30002300e+04],
#        [  1.91000000e+01,   2.30002300e+04],
#        [  1.93000000e+01,   3.30002300e+04],
#        [  1.90000000e+01,   1.90002300e+04],
#        [  1.90000000e+01,   2.00002300e+04],
#        [  1.90000000e+01,   2.50002300e+04],
#        [  1.90000000e+01,   2.60002300e+04],
#        [  9.93000000e+01,   2.00000440e+05],
#        [  7.85000000e+01,   1.67000230e+05],
#        [  7.75000000e+01,   1.65000130e+05],
#        [  6.75000000e+01,   1.78000230e+05],
# ...

# %%
# %matplotlib inline

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
from numpy import random, float

# %% [markdown]
# # image compression

# %%
from sklearn.datasets import load_sample_image
china = load_sample_image("china.jpg")

# %%
plt.imshow(china)
plt.grid(False);

# %%
china.shape
# Out:
# (427, 640, 3)

# %%
X = (china/255.0).reshape(-1, 3)

# %%
image = china[::3,::3]
n_colors = 64

# %%
X = (image / 255.0).reshape(-1, 3)

model = KMeans(n_colors)
labels = model.fit_predict(X)
colors = model.cluster_centers_
new_image = colors[labels].reshape(image.shape)
new_image = (255 * new_image).astype(np.uint8)

# %%
plt.imshow(image)
plt.grid(False)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=10)
clf.fit(X,y)


print clf.predict([[1400, 4, 0, 1 ,0, 0]])
